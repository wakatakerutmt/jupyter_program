# %% [markdown]
# # Dogs vs. Catsを畳み込みニューラルネットワークで解く

# %% [markdown]
# ## パッケージ群のインポート

# %%
import tensorflow
from tensorflow import keras
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
a = np.ones((2,1))
b = np.ones((2,))
a + 1
# Out:
# array([[2.],
#        [2.]])

# %%
import os, cv2, random
import numpy as np
import pandas as pd

# %%
from matplotlib import ticker
import seaborn as sns

# %% [markdown]
# ## トレーニング・テストデータの作成

# %%
TRAIN_DIR = "./dogscats/train/"
TEST_DIR = "./dogscats/test/"

# %%
ROWS = 64
COLS = 64
CHANNELS = 3

# %%
train_images = [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR)]

# %%
train_images
# Out:
# ['./dogscats/train/cat.0.jpg',
#  './dogscats/train/cat.1.jpg',
#  './dogscats/train/cat.10.jpg',
#  './dogscats/train/cat.100.jpg',
#  './dogscats/train/cat.1000.jpg',
#  './dogscats/train/cat.10000.jpg',
#  './dogscats/train/cat.10001.jpg',
#  './dogscats/train/cat.10002.jpg',
#  './dogscats/train/cat.10003.jpg',
#  './dogscats/train/cat.10004.jpg',
#  './dogscats/train/cat.10005.jpg',
#  './dogscats/train/cat.10006.jpg',
#  './dogscats/train/cat.10007.jpg',
#  './dogscats/train/cat.10008.jpg',
#  './dogscats/train/cat.10009.jpg',
#  './dogscats/train/cat.1001.jpg',
#  './dogscats/train/cat.10010.jpg',
#  './dogscats/train/cat.10011.jpg',
#  './dogscats/train/cat.10012.jpg',
#  './dogscats/train/cat.10013.jpg',
#  './dogscats/train/cat.10014.jpg',
#  './dogscats/train/cat.10015.jpg',
#  './dogscats/train/cat.10016.jpg',
#  './dogscats/train/cat.10017.jpg',
#  './dogscats/train/cat.10018.jpg',
#  './dogscats/train/cat.10019.jpg',
#  './dogscats/train/cat.1002.jpg',
#  './dogscats/train/cat.10020.jpg',
#  './dogscats/train/cat.10021.jpg',
#  './dogscats/train/cat.10022.jpg',
#  './dogscats/train/cat.10023.jpg',
#  './dogscats/train/cat.10024.jpg',
#  './dogscats/train/cat.10025.jpg',
#  './dogscats/train/cat.10026.jpg',
#  './dogscats/train/cat.10027.jpg',
#  './dogscats/train/cat.10028.jpg',
#  './dogscats/train/cat.10029.jpg',
#  './dogscats/train/cat.1003.jpg',
#  './dogscats/train/cat.10030.jpg',
#  './dogscats/train/cat.10031.jpg',
#  './dogscats/train/cat.10032.jpg',
#  './dogscats/train/cat.10033.jpg',
#  './dogscats/train/cat.10034.jpg',
#  './dogscats/train/cat.10035.jpg',
#  './dogscats/train/cat.10036.jpg',
#  './dogscats/train/cat.10037.jpg',
#  './dogscats/train/cat.10038.jpg',
#  './dogscats/train/cat.10039.jpg',
#  './dogscats/train/cat.1004.jpg',
#  './dogscats/train/cat.10040.jpg',
#  './dogscats/train/cat.10041.jpg',
#  './dogscats/train/cat.10042.jpg',
#  './dogscats/train/cat.10043.jpg',
#  './dogscats/train/cat.10044.jpg',
#  './dogscats/train/cat.10045.jpg',
#  './dogscats/train/cat.10046.jpg',
#  './dogscats/train/cat.10047.jpg',
#  './dogscats/train/cat.10048.jpg',
#  './dogscats/train/cat.10049.jpg',
#  './dogscats/train/cat.1005.jpg',
#  './dogscats/train/cat.10050.jpg',
#  './dogscats/train/cat.10051.jpg',
#  './dogscats/train/cat.10052.jpg',
#  './dogscats/train/cat.10053.jpg',
#  './dogscats/train/cat.10054.jpg',
#  './dogscats/train/cat.10055.jpg',
#  './dogscats/train/cat.10056.jpg',
#  './dogscats/train/cat.10057.jpg',
#  './dogscats/train/cat.10058.jpg',
#  './dogscats/train/cat.10059.jpg',
#  './dogscats/train/cat.1006.jpg',
#  './dogscats/train/cat.10060.jpg',
#  './dogscats/train/cat.10061.jpg',
#  './dogscats/train/cat.10062.jpg',
#  './dogscats/train/cat.10063.jpg',
#  './dogscats/train/cat.10064.jpg',
#  './dogscats/train/cat.10065.jpg',
#  './dogscats/train/cat.10066.jpg',
#  './dogscats/train/cat.10067.jpg',
#  './dogscats/train/cat.10068.jpg',
#  './dogscats/train/cat.10069.jpg',
#  './dogscats/train/cat.1007.jpg',
#  './dogscats/train/cat.10070.jpg',
#  './dogscats/train/cat.10071.jpg',
#  './dogscats/train/cat.10072.jpg',
#  './dogscats/train/cat.10073.jpg',
#  './dogscats/train/cat.10074.jpg',
#  './dogscats/train/cat.10075.jpg',
#  './dogscats/train/cat.10076.jpg',
#  './dogscats/train/cat.10077.jpg',
#  './dogscats/train/cat.10078.jpg',
#  './dogscats/train/cat.10079.jpg',
#  './dogscats/train/cat.1008.jpg',
#  './dogscats/train/cat.10080.jpg',
#  './dogscats/train/cat.10081.jpg',
#  './dogscats/train/cat.10082.jpg',
#  './dogscats/train/cat.10083.jpg',
#  './dogscats/train/cat.10084.jpg',
#  './dogscats/train/cat.10085.jpg',
#  './dogscats/train/cat.10086.jpg',
#  './dogscats/train/cat.10087.jpg',
#  './dogscats/train/cat.10088.jpg',
#  './dogscats/train/cat.10089.jpg',
#  './dogscats/train/cat.1009.jpg',
#  './dogscats/train/cat.10090.jpg',
#  './dogscats/train/cat.10091.jpg',
#  './dogscats/train/cat.10092.jpg',
#  './dogscats/train/cat.10093.jpg',
#  './dogscats/train/cat.10094.jpg',
#  './dogscats/train/cat.10095.jpg',
#  './dogscats/train/cat.10096.jpg',
#  './dogscats/train/cat.10097.jpg',
#  './dogscats/train/cat.10098.jpg',
#  './dogscats/train/cat.10099.jpg',
#  './dogscats/train/cat.101.jpg',
#  './dogscats/train/cat.1010.jpg',
#  './dogscats/train/cat.10100.jpg',
#  './dogscats/train/cat.10101.jpg',
#  './dogscats/train/cat.10102.jpg',
#  './dogscats/train/cat.10103.jpg',
#  './dogscats/train/cat.10104.jpg',
#  './dogscats/train/cat.10105.jpg',
#  './dogscats/train/cat.10106.jpg',
#  './dogscats/train/cat.10107.jpg',
#  './dogscats/train/cat.10108.jpg',
#  './dogscats/train/cat.10109.jpg',
#  './dogscats/train/cat.1011.jpg',
#  './dogscats/train/cat.10110.jpg',
#  './dogscats/train/cat.10111.jpg',
#  './dogscats/train/cat.10112.jpg',
#  './dogscats/train/cat.10113.jpg',
#  './dogscats/train/cat.10114.jpg',
#  './dogscats/train/cat.10115.jpg',
#  './dogscats/train/cat.10116.jpg',
#  './dogscats/train/cat.10117.jpg',
#  './dogscats/train/cat.10118.jpg',
#  './dogscats/train/cat.10119.jpg',
#  './dogscats/train/cat.1012.jpg',
#  './dogscats/train/cat.10120.jpg',
#  './dogscats/train/cat.10121.jpg',
#  './dogscats/train/cat.10122.jpg',
#  './dogscats/train/cat.10123.jpg',
#  './dogscats/train/cat.10124.jpg',
#  './dogscats/train/cat.10125.jpg',
#  './dogscats/train/cat.10126.jpg',
#  './dogscats/train/cat.10127.jpg',
#  './dogscats/train/cat.10128.jpg',
#  './dogscats/train/cat.10129.jpg',
#  './dogscats/train/cat.1013.jpg',
#  './dogscats/train/cat.10130.jpg',
#  './dogscats/train/cat.10131.jpg',
#  './dogscats/train/cat.10132.jpg',
#  './dogscats/train/cat.10133.jpg',
#  './dogscats/train/cat.10134.jpg',
#  './dogscats/train/cat.10135.jpg',
#  './dogscats/train/cat.10136.jpg',
#  './dogscats/train/cat.10137.jpg',
#  './dogscats/train/cat.10138.jpg',
#  './dogscats/train/cat.10139.jpg',
#  './dogscats/train/cat.1014.jpg',
#  './dogscats/train/cat.10140.jpg',
#  './dogscats/train/cat.10141.jpg',
#  './dogscats/train/cat.10142.jpg',
#  './dogscats/train/cat.10143.jpg',
#  './dogscats/train/cat.10144.jpg',
#  './dogscats/train/cat.10145.jpg',
#  './dogscats/train/cat.10146.jpg',
#  './dogscats/train/cat.10147.jpg',
#  './dogscats/train/cat.10148.jpg',
#  './dogscats/train/cat.10149.jpg',
#  './dogscats/train/cat.1015.jpg',
#  './dogscats/train/cat.10150.jpg',
#  './dogscats/train/cat.10151.jpg',
#  './dogscats/train/cat.10152.jpg',
#  './dogscats/train/cat.10153.jpg',
#  './dogscats/train/cat.10154.jpg',
#  './dogscats/train/cat.10155.jpg',
#  './dogscats/train/cat.10156.jpg',
#  './dogscats/train/cat.10157.jpg',
#  './dogscats/train/cat.10158.jpg',
#  './dogscats/train/cat.10159.jpg',
#  './dogscats/train/cat.1016.jpg',
#  './dogscats/train/cat.10160.jpg',
#  './dogscats/train/cat.10161.jpg',
#  './dogscats/train/cat.10162.jpg',
#  './dogscats/train/cat.10163.jpg',
#  './dogscats/train/cat.10164.jpg',
#  './dogscats/train/cat.10165.jpg',
#  './dogscats/train/cat.10166.jpg',
#  './dogscats/train/cat.10167.jpg',
#  './dogscats/train/cat.10168.jpg',
#  './dogscats/train/cat.10169.jpg',
#  './dogscats/train/cat.1017.jpg',
#  './dogscats/train/cat.10170.jpg',
#  './dogscats/train/cat.10171.jpg',
#  './dogscats/train/cat.10172.jpg',
#  './dogscats/train/cat.10173.jpg',
#  './dogscats/train/cat.10174.jpg',
#  './dogscats/train/cat.10175.jpg',
#  './dogscats/train/cat.10176.jpg',
#  './dogscats/train/cat.10177.jpg',
#  './dogscats/train/cat.10178.jpg',
#  './dogscats/train/cat.10179.jpg',
#  './dogscats/train/cat.1018.jpg',
#  './dogscats/train/cat.10180.jpg',
#  './dogscats/train/cat.10181.jpg',
#  './dogscats/train/cat.10182.jpg',
#  './dogscats/train/cat.10183.jpg',
#  './dogscats/train/cat.10184.jpg',
#  './dogscats/train/cat.10185.jpg',
#  './dogscats/train/cat.10186.jpg',
#  './dogscats/train/cat.10187.jpg',
#  './dogscats/train/cat.10188.jpg',
#  './dogscats/train/cat.10189.jpg',
#  './dogscats/train/cat.1019.jpg',
#  './dogscats/train/cat.10190.jpg',
#  './dogscats/train/cat.10191.jpg',
#  './dogscats/train/cat.10192.jpg',
#  './dogscats/train/cat.10193.jpg',
#  './dogscats/train/cat.10194.jpg',
#  './dogscats/train/cat.10195.jpg',
#  './dogscats/train/cat.10196.jpg',
#  './dogscats/train/cat.10197.jpg',
#  './dogscats/train/cat.10198.jpg',
#  './dogscats/train/cat.10199.jpg',
#  './dogscats/train/cat.102.jpg',
#  './dogscats/train/cat.1020.jpg',
#  './dogscats/train/cat.10200.jpg',
#  './dogscats/train/cat.10201.jpg',
#  './dogscats/train/cat.10202.jpg',
#  './dogscats/train/cat.10203.jpg',
#  './dogscats/train/cat.10204.jpg',
#  './dogscats/train/cat.10205.jpg',
#  './dogscats/train/cat.10206.jpg',
#  './dogscats/train/cat.10207.jpg',
#  './dogscats/train/cat.10208.jpg',
#  './dogscats/train/cat.10209.jpg',
#  './dogscats/train/cat.1021.jpg',
#  './dogscats/train/cat.10210.jpg',
#  './dogscats/train/cat.10211.jpg',
#  './dogscats/train/cat.10212.jpg',
#  './dogscats/train/cat.10213.jpg',
#  './dogscats/train/cat.10214.jpg',
#  './dogscats/train/cat.10215.jpg',
#  './dogscats/train/cat.10216.jpg',
#  './dogscats/train/cat.10217.jpg',
#  './dogscats/train/cat.10218.jpg',
#  './dogscats/train/cat.10219.jpg',
#  './dogscats/train/cat.1022.jpg',
#  './dogscats/train/cat.10220.jpg',
#  './dogscats/train/cat.10221.jpg',
#  './dogscats/train/cat.10222.jpg',
#  './dogscats/train/cat.10223.jpg',
#  './dogscats/train/cat.10224.jpg',
#  './dogscats/train/cat.10225.jpg',
#  './dogscats/train/cat.10226.jpg',
#  './dogscats/train/cat.10227.jpg',
#  './dogscats/train/cat.10228.jpg',
#  './dogscats/train/cat.10229.jpg',
#  './dogscats/train/cat.1023.jpg',
#  './dogscats/train/cat.10230.jpg',
#  './dogscats/train/cat.10231.jpg',
#  './dogscats/train/cat.10232.jpg',
#  './dogscats/train/cat.10233.jpg',
#  './dogscats/train/cat.10234.jpg',
#  './dogscats/train/cat.10235.jpg',
#  './dogscats/train/cat.10236.jpg',
#  './dogscats/train/cat.10237.jpg',
#  './dogscats/train/cat.10238.jpg',
#  './dogscats/train/cat.10239.jpg',
#  './dogscats/train/cat.1024.jpg',
#  './dogscats/train/cat.10240.jpg',
#  './dogscats/train/cat.10241.jpg',
#  './dogscats/train/cat.10242.jpg',
#  './dogscats/train/cat.10243.jpg',
#  './dogscats/train/cat.10244.jpg',
#  './dogscats/train/cat.10245.jpg',
#  './dogscats/train/cat.10246.jpg',
#  './dogscats/train/cat.10247.jpg',
#  './dogscats/train/cat.10248.jpg',
#  './dogscats/train/cat.10249.jpg',
#  './dogscats/train/cat.1025.jpg',
#  './dogscats/train/cat.10250.jpg',
#  './dogscats/train/cat.10251.jpg',
#  './dogscats/train/cat.10252.jpg',
#  './dogscats/train/cat.10253.jpg',
#  './dogscats/train/cat.10254.jpg',
#  './dogscats/train/cat.10255.jpg',
#  './dogscats/train/cat.10256.jpg',
#  './dogscats/train/cat.10257.jpg',
#  './dogscats/train/cat.10258.jpg',
#  './dogscats/train/cat.10259.jpg',
#  './dogscats/train/cat.1026.jpg',
#  './dogscats/train/cat.10260.jpg',
#  './dogscats/train/cat.10261.jpg',
#  './dogscats/train/cat.10262.jpg',
#  './dogscats/train/cat.10263.jpg',
#  './dogscats/train/cat.10264.jpg',
#  './dogscats/train/cat.10265.jpg',
#  './dogscats/train/cat.10266.jpg',
#  './dogscats/train/cat.10267.jpg',
#  './dogscats/train/cat.10268.jpg',
#  './dogscats/train/cat.10269.jpg',
#  './dogscats/train/cat.1027.jpg',
#  './dogscats/train/cat.10270.jpg',
#  './dogscats/train/cat.10271.jpg',
#  './dogscats/train/cat.10272.jpg',
#  './dogscats/train/cat.10273.jpg',
#  './dogscats/train/cat.10274.jpg',
#  './dogscats/train/cat.10275.jpg',
#  './dogscats/train/cat.10276.jpg',
#  './dogscats/train/cat.10277.jpg',
#  './dogscats/train/cat.10278.jpg',
#  './dogscats/train/cat.10279.jpg',
#  './dogscats/train/cat.1028.jpg',
#  './dogscats/train/cat.10280.jpg',
#  './dogscats/train/cat.10281.jpg',
#  './dogscats/train/cat.10282.jpg',
#  './dogscats/train/cat.10283.jpg',
#  './dogscats/train/cat.10284.jpg',
#  './dogscats/train/cat.10285.jpg',
#  './dogscats/train/cat.10286.jpg',
#  './dogscats/train/cat.10287.jpg',
#  './dogscats/train/cat.10288.jpg',
#  './dogscats/train/cat.10289.jpg',
#  './dogscats/train/cat.1029.jpg',
#  './dogscats/train/cat.10290.jpg',
#  './dogscats/train/cat.10291.jpg',
#  './dogscats/train/cat.10292.jpg',
#  './dogscats/train/cat.10293.jpg',
#  './dogscats/train/cat.10294.jpg',
#  './dogscats/train/cat.10295.jpg',
#  './dogscats/train/cat.10296.jpg',
#  './dogscats/train/cat.10297.jpg',
#  './dogscats/train/cat.10298.jpg',
#  './dogscats/train/cat.10299.jpg',
#  './dogscats/train/cat.103.jpg',
#  './dogscats/train/cat.1030.jpg',
#  './dogscats/train/cat.10300.jpg',
#  './dogscats/train/cat.10301.jpg',
#  './dogscats/train/cat.10302.jpg',
#  './dogscats/train/cat.10303.jpg',
#  './dogscats/train/cat.10304.jpg',
#  './dogscats/train/cat.10305.jpg',
#  './dogscats/train/cat.10306.jpg',
#  './dogscats/train/cat.10307.jpg',
#  './dogscats/train/cat.10308.jpg',
#  './dogscats/train/cat.10309.jpg',
#  './dogscats/train/cat.1031.jpg',
#  './dogscats/train/cat.10310.jpg',
#  './dogscats/train/cat.10311.jpg',
#  './dogscats/train/cat.10312.jpg',
#  './dogscats/train/cat.10313.jpg',
#  './dogscats/train/cat.10314.jpg',
#  './dogscats/train/cat.10315.jpg',
#  './dogscats/train/cat.10316.jpg',
#  './dogscats/train/cat.10317.jpg',
#  './dogscats/train/cat.10318.jpg',
#  './dogscats/train/cat.10319.jpg',
#  './dogscats/train/cat.1032.jpg',
#  './dogscats/train/cat.10320.jpg',
#  './dogscats/train/cat.10321.jpg',
#  './dogscats/train/cat.10322.jpg',
#  './dogscats/train/cat.10323.jpg',
#  './dogscats/train/cat.10324.jpg',
#  './dogscats/train/cat.10325.jpg',
#  './dogscats/train/cat.10326.jpg',
#  './dogscats/train/cat.10327.jpg',
#  './dogscats/train/cat.10328.jpg',
#  './dogscats/train/cat.10329.jpg',
#  './dogscats/train/cat.1033.jpg',
#  './dogscats/train/cat.10330.jpg',
#  './dogscats/train/cat.10331.jpg',
#  './dogscats/train/cat.10332.jpg',
#  './dogscats/train/cat.10333.jpg',
#  './dogscats/train/cat.10334.jpg',
#  './dogscats/train/cat.10335.jpg',
#  './dogscats/train/cat.10336.jpg',
#  './dogscats/train/cat.10337.jpg',
#  './dogscats/train/cat.10338.jpg',
#  './dogscats/train/cat.10339.jpg',
#  './dogscats/train/cat.1034.jpg',
#  './dogscats/train/cat.10340.jpg',
#  './dogscats/train/cat.10341.jpg',
#  './dogscats/train/cat.10342.jpg',
#  './dogscats/train/cat.10343.jpg',
#  './dogscats/train/cat.10344.jpg',
#  './dogscats/train/cat.10345.jpg',
#  './dogscats/train/cat.10346.jpg',
#  './dogscats/train/cat.10347.jpg',
#  './dogscats/train/cat.10348.jpg',
#  './dogscats/train/cat.10349.jpg',
#  './dogscats/train/cat.1035.jpg',
#  './dogscats/train/cat.10350.jpg',
#  './dogscats/train/cat.10351.jpg',
#  './dogscats/train/cat.10352.jpg',
#  './dogscats/train/cat.10353.jpg',
#  './dogscats/train/cat.10354.jpg',
#  './dogscats/train/cat.10355.jpg',
#  './dogscats/train/cat.10356.jpg',
#  './dogscats/train/cat.10357.jpg',
#  './dogscats/train/cat.10358.jpg',
#  './dogscats/train/cat.10359.jpg',
#  './dogscats/train/cat.1036.jpg',
#  './dogscats/train/cat.10360.jpg',
#  './dogscats/train/cat.10361.jpg',
#  './dogscats/train/cat.10362.jpg',
#  './dogscats/train/cat.10363.jpg',
#  './dogscats/train/cat.10364.jpg',
#  './dogscats/train/cat.10365.jpg',
#  './dogscats/train/cat.10366.jpg',
#  './dogscats/train/cat.10367.jpg',
#  './dogscats/train/cat.10368.jpg',
#  './dogscats/train/cat.10369.jpg',
#  './dogscats/train/cat.1037.jpg',
#  './dogscats/train/cat.10370.jpg',
#  './dogscats/train/cat.10371.jpg',
#  './dogscats/train/cat.10372.jpg',
#  './dogscats/train/cat.10373.jpg',
#  './dogscats/train/cat.10374.jpg',
#  './dogscats/train/cat.10375.jpg',
#  './dogscats/train/cat.10376.jpg',
#  './dogscats/train/cat.10377.jpg',
#  './dogscats/train/cat.10378.jpg',
#  './dogscats/train/cat.10379.jpg',
#  './dogscats/train/cat.1038.jpg',
#  './dogscats/train/cat.10380.jpg',
#  './dogscats/train/cat.10381.jpg',
#  './dogscats/train/cat.10382.jpg',
#  './dogscats/train/cat.10383.jpg',
#  './dogscats/train/cat.10384.jpg',
#  './dogscats/train/cat.10385.jpg',
#  './dogscats/train/cat.10386.jpg',
#  './dogscats/train/cat.10387.jpg',
#  './dogscats/train/cat.10388.jpg',
#  './dogscats/train/cat.10389.jpg',
#  './dogscats/train/cat.1039.jpg',
#  './dogscats/train/cat.10390.jpg',
#  './dogscats/train/cat.10391.jpg',
#  './dogscats/train/cat.10392.jpg',
#  './dogscats/train/cat.10393.jpg',
#  './dogscats/train/cat.10394.jpg',
#  './dogscats/train/cat.10395.jpg',
#  './dogscats/train/cat.10396.jpg',
#  './dogscats/train/cat.10397.jpg',
#  './dogscats/train/cat.10398.jpg',
#  './dogscats/train/cat.10399.jpg',
#  './dogscats/train/cat.104.jpg',
#  './dogscats/train/cat.1040.jpg',
#  './dogscats/train/cat.10400.jpg',
#  './dogscats/train/cat.10401.jpg',
#  './dogscats/train/cat.10402.jpg',
#  './dogscats/train/cat.10403.jpg',
#  './dogscats/train/cat.10404.jpg',
#  './dogscats/train/cat.10405.jpg',
#  './dogscats/train/cat.10406.jpg',
#  './dogscats/train/cat.10407.jpg',
#  './dogscats/train/cat.10408.jpg',
#  './dogscats/train/cat.10409.jpg',
#  './dogscats/train/cat.1041.jpg',
#  './dogscats/train/cat.10410.jpg',
#  './dogscats/train/cat.10411.jpg',
#  './dogscats/train/cat.10412.jpg',
#  './dogscats/train/cat.10413.jpg',
#  './dogscats/train/cat.10414.jpg',
#  './dogscats/train/cat.10415.jpg',
#  './dogscats/train/cat.10416.jpg',
#  './dogscats/train/cat.10417.jpg',
#  './dogscats/train/cat.10418.jpg',
#  './dogscats/train/cat.10419.jpg',
#  './dogscats/train/cat.1042.jpg',
#  './dogscats/train/cat.10420.jpg',
#  './dogscats/train/cat.10421.jpg',
#  './dogscats/train/cat.10422.jpg',
#  './dogscats/train/cat.10423.jpg',
#  './dogscats/train/cat.10424.jpg',
#  './dogscats/train/cat.10425.jpg',
#  './dogscats/train/cat.10426.jpg',
#  './dogscats/train/cat.10427.jpg',
#  './dogscats/train/cat.10428.jpg',
#  './dogscats/train/cat.10429.jpg',
#  './dogscats/train/cat.1043.jpg',
#  './dogscats/train/cat.10430.jpg',
#  './dogscats/train/cat.10431.jpg',
#  './dogscats/train/cat.10432.jpg',
#  './dogscats/train/cat.10433.jpg',
#  './dogscats/train/cat.10434.jpg',
#  './dogscats/train/cat.10435.jpg',
#  './dogscats/train/cat.10436.jpg',
#  './dogscats/train/cat.10437.jpg',
#  './dogscats/train/cat.10438.jpg',
#  './dogscats/train/cat.10439.jpg',
#  './dogscats/train/cat.1044.jpg',
#  './dogscats/train/cat.10440.jpg',
#  './dogscats/train/cat.10441.jpg',
#  './dogscats/train/cat.10442.jpg',
#  './dogscats/train/cat.10443.jpg',
#  './dogscats/train/cat.10444.jpg',
#  './dogscats/train/cat.10445.jpg',
#  './dogscats/train/cat.10446.jpg',
#  './dogscats/train/cat.10447.jpg',
#  './dogscats/train/cat.10448.jpg',
#  './dogscats/train/cat.10449.jpg',
#  './dogscats/train/cat.1045.jpg',
#  './dogscats/train/cat.10450.jpg',
#  './dogscats/train/cat.10451.jpg',
#  './dogscats/train/cat.10452.jpg',
#  './dogscats/train/cat.10453.jpg',
#  './dogscats/train/cat.10454.jpg',
#  './dogscats/train/cat.10455.jpg',
#  './dogscats/train/cat.10456.jpg',
#  './dogscats/train/cat.10457.jpg',
#  './dogscats/train/cat.10458.jpg',
#  './dogscats/train/cat.10459.jpg',
#  './dogscats/train/cat.1046.jpg',
#  './dogscats/train/cat.10460.jpg',
#  './dogscats/train/cat.10461.jpg',
#  './dogscats/train/cat.10462.jpg',
#  './dogscats/train/cat.10463.jpg',
#  './dogscats/train/cat.10464.jpg',
#  './dogscats/train/cat.10465.jpg',
#  './dogscats/train/cat.10466.jpg',
#  './dogscats/train/cat.10467.jpg',
#  './dogscats/train/cat.10468.jpg',
#  './dogscats/train/cat.10469.jpg',
#  './dogscats/train/cat.1047.jpg',
#  './dogscats/train/cat.10470.jpg',
#  './dogscats/train/cat.10471.jpg',
#  './dogscats/train/cat.10472.jpg',
#  './dogscats/train/cat.10473.jpg',
#  './dogscats/train/cat.10474.jpg',
#  './dogscats/train/cat.10475.jpg',
#  './dogscats/train/cat.10476.jpg',
#  './dogscats/train/cat.10477.jpg',
#  './dogscats/train/cat.10478.jpg',
#  './dogscats/train/cat.10479.jpg',
#  './dogscats/train/cat.1048.jpg',
#  './dogscats/train/cat.10480.jpg',
#  './dogscats/train/cat.10481.jpg',
#  './dogscats/train/cat.10482.jpg',
#  './dogscats/train/cat.10483.jpg',
#  './dogscats/train/cat.10484.jpg',
#  './dogscats/train/cat.10485.jpg',
#  './dogscats/train/cat.10486.jpg',
#  './dogscats/train/cat.10487.jpg',
#  './dogscats/train/cat.10488.jpg',
#  './dogscats/train/cat.10489.jpg',
#  './dogscats/train/cat.1049.jpg',
#  './dogscats/train/cat.10490.jpg',
#  './dogscats/train/cat.10491.jpg',
#  './dogscats/train/cat.10492.jpg',
#  './dogscats/train/cat.10493.jpg',
#  './dogscats/train/cat.10494.jpg',
#  './dogscats/train/cat.10495.jpg',
#  './dogscats/train/cat.10496.jpg',
#  './dogscats/train/cat.10497.jpg',
#  './dogscats/train/cat.10498.jpg',
#  './dogscats/train/cat.10499.jpg',
#  './dogscats/train/cat.105.jpg',
#  './dogscats/train/cat.1050.jpg',
#  './dogscats/train/cat.10500.jpg',
#  './dogscats/train/cat.10501.jpg',
#  './dogscats/train/cat.10502.jpg',
#  './dogscats/train/cat.10503.jpg',
#  './dogscats/train/cat.10504.jpg',
#  './dogscats/train/cat.10505.jpg',
#  './dogscats/train/cat.10506.jpg',
#  './dogscats/train/cat.10507.jpg',
#  './dogscats/train/cat.10508.jpg',
#  './dogscats/train/cat.10509.jpg',
#  './dogscats/train/cat.1051.jpg',
#  './dogscats/train/cat.10510.jpg',
#  './dogscats/train/cat.10511.jpg',
#  './dogscats/train/cat.10512.jpg',
#  './dogscats/train/cat.10513.jpg',
#  './dogscats/train/cat.10514.jpg',
#  './dogscats/train/cat.10515.jpg',
#  './dogscats/train/cat.10516.jpg',
#  './dogscats/train/cat.10517.jpg',
#  './dogscats/train/cat.10518.jpg',
#  './dogscats/train/cat.10519.jpg',
#  './dogscats/train/cat.1052.jpg',
#  './dogscats/train/cat.10520.jpg',
#  './dogscats/train/cat.10521.jpg',
#  './dogscats/train/cat.10522.jpg',
#  './dogscats/train/cat.10523.jpg',
#  './dogscats/train/cat.10524.jpg',
#  './dogscats/train/cat.10525.jpg',
#  './dogscats/train/cat.10526.jpg',
#  './dogscats/train/cat.10527.jpg',
#  './dogscats/train/cat.10528.jpg',
#  './dogscats/train/cat.10529.jpg',
#  './dogscats/train/cat.1053.jpg',
#  './dogscats/train/cat.10530.jpg',
#  './dogscats/train/cat.10531.jpg',
#  './dogscats/train/cat.10532.jpg',
#  './dogscats/train/cat.10533.jpg',
#  './dogscats/train/cat.10534.jpg',
#  './dogscats/train/cat.10535.jpg',
#  './dogscats/train/cat.10536.jpg',
#  './dogscats/train/cat.10537.jpg',
#  './dogscats/train/cat.10538.jpg',
#  './dogscats/train/cat.10539.jpg',
#  './dogscats/train/cat.1054.jpg',
#  './dogscats/train/cat.10540.jpg',
#  './dogscats/train/cat.10541.jpg',
#  './dogscats/train/cat.10542.jpg',
#  './dogscats/train/cat.10543.jpg',
#  './dogscats/train/cat.10544.jpg',
#  './dogscats/train/cat.10545.jpg',
#  './dogscats/train/cat.10546.jpg',
#  './dogscats/train/cat.10547.jpg',
#  './dogscats/train/cat.10548.jpg',
#  './dogscats/train/cat.10549.jpg',
#  './dogscats/train/cat.1055.jpg',
#  './dogscats/train/cat.10550.jpg',
#  './dogscats/train/cat.10551.jpg',
#  './dogscats/train/cat.10552.jpg',
#  './dogscats/train/cat.10553.jpg',
#  './dogscats/train/cat.10554.jpg',
#  './dogscats/train/cat.10555.jpg',
#  './dogscats/train/cat.10556.jpg',
#  './dogscats/train/cat.10557.jpg',
#  './dogscats/train/cat.10558.jpg',
#  './dogscats/train/cat.10559.jpg',
#  './dogscats/train/cat.1056.jpg',
#  './dogscats/train/cat.10560.jpg',
#  './dogscats/train/cat.10561.jpg',
#  './dogscats/train/cat.10562.jpg',
#  './dogscats/train/cat.10563.jpg',
#  './dogscats/train/cat.10564.jpg',
#  './dogscats/train/cat.10565.jpg',
#  './dogscats/train/cat.10566.jpg',
#  './dogscats/train/cat.10567.jpg',
#  './dogscats/train/cat.10568.jpg',
#  './dogscats/train/cat.10569.jpg',
#  './dogscats/train/cat.1057.jpg',
#  './dogscats/train/cat.10570.jpg',
#  './dogscats/train/cat.10571.jpg',
#  './dogscats/train/cat.10572.jpg',
#  './dogscats/train/cat.10573.jpg',
#  './dogscats/train/cat.10574.jpg',
#  './dogscats/train/cat.10575.jpg',
#  './dogscats/train/cat.10576.jpg',
#  './dogscats/train/cat.10577.jpg',
#  './dogscats/train/cat.10578.jpg',
#  './dogscats/train/cat.10579.jpg',
#  './dogscats/train/cat.1058.jpg',
#  './dogscats/train/cat.10580.jpg',
#  './dogscats/train/cat.10581.jpg',
#  './dogscats/train/cat.10582.jpg',
#  './dogscats/train/cat.10583.jpg',
#  './dogscats/train/cat.10584.jpg',
#  './dogscats/train/cat.10585.jpg',
#  './dogscats/train/cat.10586.jpg',
#  './dogscats/train/cat.10587.jpg',
#  './dogscats/train/cat.10588.jpg',
#  './dogscats/train/cat.10589.jpg',
#  './dogscats/train/cat.1059.jpg',
#  './dogscats/train/cat.10590.jpg',
#  './dogscats/train/cat.10591.jpg',
#  './dogscats/train/cat.10592.jpg',
#  './dogscats/train/cat.10593.jpg',
#  './dogscats/train/cat.10594.jpg',
#  './dogscats/train/cat.10595.jpg',
#  './dogscats/train/cat.10596.jpg',
#  './dogscats/train/cat.10597.jpg',
#  './dogscats/train/cat.10598.jpg',
#  './dogscats/train/cat.10599.jpg',
#  './dogscats/train/cat.106.jpg',
#  './dogscats/train/cat.1060.jpg',
#  './dogscats/train/cat.10600.jpg',
#  './dogscats/train/cat.10601.jpg',
#  './dogscats/train/cat.10602.jpg',
#  './dogscats/train/cat.10603.jpg',
#  './dogscats/train/cat.10604.jpg',
#  './dogscats/train/cat.10605.jpg',
#  './dogscats/train/cat.10606.jpg',
#  './dogscats/train/cat.10607.jpg',
#  './dogscats/train/cat.10608.jpg',
#  './dogscats/train/cat.10609.jpg',
#  './dogscats/train/cat.1061.jpg',
#  './dogscats/train/cat.10610.jpg',
#  './dogscats/train/cat.10611.jpg',
#  './dogscats/train/cat.10612.jpg',
#  './dogscats/train/cat.10613.jpg',
#  './dogscats/train/cat.10614.jpg',
#  './dogscats/train/cat.10615.jpg',
#  './dogscats/train/cat.10616.jpg',
#  './dogscats/train/cat.10617.jpg',
#  './dogscats/train/cat.10618.jpg',
#  './dogscats/train/cat.10619.jpg',
#  './dogscats/train/cat.1062.jpg',
#  './dogscats/train/cat.10620.jpg',
#  './dogscats/train/cat.10621.jpg',
#  './dogscats/train/cat.10622.jpg',
#  './dogscats/train/cat.10623.jpg',
#  './dogscats/train/cat.10624.jpg',
#  './dogscats/train/cat.10625.jpg',
#  './dogscats/train/cat.10626.jpg',
#  './dogscats/train/cat.10627.jpg',
#  './dogscats/train/cat.10628.jpg',
#  './dogscats/train/cat.10629.jpg',
#  './dogscats/train/cat.1063.jpg',
#  './dogscats/train/cat.10630.jpg',
#  './dogscats/train/cat.10631.jpg',
#  './dogscats/train/cat.10632.jpg',
#  './dogscats/train/cat.10633.jpg',
#  './dogscats/train/cat.10634.jpg',
#  './dogscats/train/cat.10635.jpg',
#  './dogscats/train/cat.10636.jpg',
#  './dogscats/train/cat.10637.jpg',
#  './dogscats/train/cat.10638.jpg',
#  './dogscats/train/cat.10639.jpg',
#  './dogscats/train/cat.1064.jpg',
#  './dogscats/train/cat.10640.jpg',
#  './dogscats/train/cat.10641.jpg',
#  './dogscats/train/cat.10642.jpg',
#  './dogscats/train/cat.10643.jpg',
#  './dogscats/train/cat.10644.jpg',
#  './dogscats/train/cat.10645.jpg',
#  './dogscats/train/cat.10646.jpg',
#  './dogscats/train/cat.10647.jpg',
#  './dogscats/train/cat.10648.jpg',
#  './dogscats/train/cat.10649.jpg',
#  './dogscats/train/cat.1065.jpg',
#  './dogscats/train/cat.10650.jpg',
#  './dogscats/train/cat.10651.jpg',
#  './dogscats/train/cat.10652.jpg',
#  './dogscats/train/cat.10653.jpg',
#  './dogscats/train/cat.10654.jpg',
#  './dogscats/train/cat.10655.jpg',
#  './dogscats/train/cat.10656.jpg',
#  './dogscats/train/cat.10657.jpg',
#  './dogscats/train/cat.10658.jpg',
#  './dogscats/train/cat.10659.jpg',
#  './dogscats/train/cat.1066.jpg',
#  './dogscats/train/cat.10660.jpg',
#  './dogscats/train/cat.10661.jpg',
#  './dogscats/train/cat.10662.jpg',
#  './dogscats/train/cat.10663.jpg',
#  './dogscats/train/cat.10664.jpg',
#  './dogscats/train/cat.10665.jpg',
#  './dogscats/train/cat.10666.jpg',
#  './dogscats/train/cat.10667.jpg',
#  './dogscats/train/cat.10668.jpg',
#  './dogscats/train/cat.10669.jpg',
#  './dogscats/train/cat.1067.jpg',
#  './dogscats/train/cat.10670.jpg',
#  './dogscats/train/cat.10671.jpg',
#  './dogscats/train/cat.10672.jpg',
#  './dogscats/train/cat.10673.jpg',
#  './dogscats/train/cat.10674.jpg',
#  './dogscats/train/cat.10675.jpg',
#  './dogscats/train/cat.10676.jpg',
#  './dogscats/train/cat.10677.jpg',
#  './dogscats/train/cat.10678.jpg',
#  './dogscats/train/cat.10679.jpg',
#  './dogscats/train/cat.1068.jpg',
#  './dogscats/train/cat.10680.jpg',
#  './dogscats/train/cat.10681.jpg',
#  './dogscats/train/cat.10682.jpg',
#  './dogscats/train/cat.10683.jpg',
#  './dogscats/train/cat.10684.jpg',
#  './dogscats/train/cat.10685.jpg',
#  './dogscats/train/cat.10686.jpg',
#  './dogscats/train/cat.10687.jpg',
#  './dogscats/train/cat.10688.jpg',
#  './dogscats/train/cat.10689.jpg',
#  './dogscats/train/cat.1069.jpg',
#  './dogscats/train/cat.10690.jpg',
#  './dogscats/train/cat.10691.jpg',
#  './dogscats/train/cat.10692.jpg',
#  './dogscats/train/cat.10693.jpg',
#  './dogscats/train/cat.10694.jpg',
#  './dogscats/train/cat.10695.jpg',
#  './dogscats/train/cat.10696.jpg',
#  './dogscats/train/cat.10697.jpg',
#  './dogscats/train/cat.10698.jpg',
#  './dogscats/train/cat.10699.jpg',
#  './dogscats/train/cat.107.jpg',
#  './dogscats/train/cat.1070.jpg',
#  './dogscats/train/cat.10700.jpg',
#  './dogscats/train/cat.10701.jpg',
#  './dogscats/train/cat.10702.jpg',
#  './dogscats/train/cat.10703.jpg',
#  './dogscats/train/cat.10704.jpg',
#  './dogscats/train/cat.10705.jpg',
#  './dogscats/train/cat.10706.jpg',
#  './dogscats/train/cat.10707.jpg',
#  './dogscats/train/cat.10708.jpg',
#  './dogscats/train/cat.10709.jpg',
#  './dogscats/train/cat.1071.jpg',
#  './dogscats/train/cat.10710.jpg',
#  './dogscats/train/cat.10711.jpg',
#  './dogscats/train/cat.10712.jpg',
#  './dogscats/train/cat.10713.jpg',
#  './dogscats/train/cat.10714.jpg',
#  './dogscats/train/cat.10715.jpg',
#  './dogscats/train/cat.10716.jpg',
#  './dogscats/train/cat.10717.jpg',
#  './dogscats/train/cat.10718.jpg',
#  './dogscats/train/cat.10719.jpg',
#  './dogscats/train/cat.1072.jpg',
#  './dogscats/train/cat.10720.jpg',
#  './dogscats/train/cat.10721.jpg',
#  './dogscats/train/cat.10722.jpg',
#  './dogscats/train/cat.10723.jpg',
#  './dogscats/train/cat.10724.jpg',
#  './dogscats/train/cat.10725.jpg',
#  './dogscats/train/cat.10726.jpg',
#  './dogscats/train/cat.10727.jpg',
#  './dogscats/train/cat.10728.jpg',
#  './dogscats/train/cat.10729.jpg',
#  './dogscats/train/cat.1073.jpg',
#  './dogscats/train/cat.10730.jpg',
#  './dogscats/train/cat.10731.jpg',
#  './dogscats/train/cat.10732.jpg',
#  './dogscats/train/cat.10733.jpg',
#  './dogscats/train/cat.10734.jpg',
#  './dogscats/train/cat.10735.jpg',
#  './dogscats/train/cat.10736.jpg',
#  './dogscats/train/cat.10737.jpg',
#  './dogscats/train/cat.10738.jpg',
#  './dogscats/train/cat.10739.jpg',
#  './dogscats/train/cat.1074.jpg',
#  './dogscats/train/cat.10740.jpg',
#  './dogscats/train/cat.10741.jpg',
#  './dogscats/train/cat.10742.jpg',
#  './dogscats/train/cat.10743.jpg',
#  './dogscats/train/cat.10744.jpg',
#  './dogscats/train/cat.10745.jpg',
#  './dogscats/train/cat.10746.jpg',
#  './dogscats/train/cat.10747.jpg',
#  './dogscats/train/cat.10748.jpg',
#  './dogscats/train/cat.10749.jpg',
#  './dogscats/train/cat.1075.jpg',
#  './dogscats/train/cat.10750.jpg',
#  './dogscats/train/cat.10751.jpg',
#  './dogscats/train/cat.10752.jpg',
#  './dogscats/train/cat.10753.jpg',
#  './dogscats/train/cat.10754.jpg',
#  './dogscats/train/cat.10755.jpg',
#  './dogscats/train/cat.10756.jpg',
#  './dogscats/train/cat.10757.jpg',
#  './dogscats/train/cat.10758.jpg',
#  './dogscats/train/cat.10759.jpg',
#  './dogscats/train/cat.1076.jpg',
#  './dogscats/train/cat.10760.jpg',
#  './dogscats/train/cat.10761.jpg',
#  './dogscats/train/cat.10762.jpg',
#  './dogscats/train/cat.10763.jpg',
#  './dogscats/train/cat.10764.jpg',
#  './dogscats/train/cat.10765.jpg',
#  './dogscats/train/cat.10766.jpg',
#  './dogscats/train/cat.10767.jpg',
#  './dogscats/train/cat.10768.jpg',
#  './dogscats/train/cat.10769.jpg',
#  './dogscats/train/cat.1077.jpg',
#  './dogscats/train/cat.10770.jpg',
#  './dogscats/train/cat.10771.jpg',
#  './dogscats/train/cat.10772.jpg',
#  './dogscats/train/cat.10773.jpg',
#  './dogscats/train/cat.10774.jpg',
#  './dogscats/train/cat.10775.jpg',
#  './dogscats/train/cat.10776.jpg',
#  './dogscats/train/cat.10777.jpg',
#  './dogscats/train/cat.10778.jpg',
#  './dogscats/train/cat.10779.jpg',
#  './dogscats/train/cat.1078.jpg',
#  './dogscats/train/cat.10780.jpg',
#  './dogscats/train/cat.10781.jpg',
#  './dogscats/train/cat.10782.jpg',
#  './dogscats/train/cat.10783.jpg',
#  './dogscats/train/cat.10784.jpg',
#  './dogscats/train/cat.10785.jpg',
#  './dogscats/train/cat.10786.jpg',
#  './dogscats/train/cat.10787.jpg',
#  './dogscats/train/cat.10788.jpg',
#  './dogscats/train/cat.10789.jpg',
#  './dogscats/train/cat.1079.jpg',
#  './dogscats/train/cat.10790.jpg',
#  './dogscats/train/cat.10791.jpg',
#  './dogscats/train/cat.10792.jpg',
#  './dogscats/train/cat.10793.jpg',
#  './dogscats/train/cat.10794.jpg',
#  './dogscats/train/cat.10795.jpg',
#  './dogscats/train/cat.10796.jpg',
#  './dogscats/train/cat.10797.jpg',
#  './dogscats/train/cat.10798.jpg',
#  './dogscats/train/cat.10799.jpg',
#  './dogscats/train/cat.108.jpg',
#  './dogscats/train/cat.1080.jpg',
#  './dogscats/train/cat.10800.jpg',
#  './dogscats/train/cat.10801.jpg',
#  './dogscats/train/cat.10802.jpg',
#  './dogscats/train/cat.10803.jpg',
#  './dogscats/train/cat.10804.jpg',
#  './dogscats/train/cat.10805.jpg',
#  './dogscats/train/cat.10806.jpg',
#  './dogscats/train/cat.10807.jpg',
#  './dogscats/train/cat.10808.jpg',
#  './dogscats/train/cat.10809.jpg',
#  './dogscats/train/cat.1081.jpg',
#  './dogscats/train/cat.10810.jpg',
#  './dogscats/train/cat.10811.jpg',
#  './dogscats/train/cat.10812.jpg',
#  './dogscats/train/cat.10813.jpg',
#  './dogscats/train/cat.10814.jpg',
#  './dogscats/train/cat.10815.jpg',
#  './dogscats/train/cat.10816.jpg',
#  './dogscats/train/cat.10817.jpg',
#  './dogscats/train/cat.10818.jpg',
#  './dogscats/train/cat.10819.jpg',
#  './dogscats/train/cat.1082.jpg',
#  './dogscats/train/cat.10820.jpg',
#  './dogscats/train/cat.10821.jpg',
#  './dogscats/train/cat.10822.jpg',
#  './dogscats/train/cat.10823.jpg',
#  './dogscats/train/cat.10824.jpg',
#  './dogscats/train/cat.10825.jpg',
#  './dogscats/train/cat.10826.jpg',
#  './dogscats/train/cat.10827.jpg',
#  './dogscats/train/cat.10828.jpg',
#  './dogscats/train/cat.10829.jpg',
#  './dogscats/train/cat.1083.jpg',
#  './dogscats/train/cat.10830.jpg',
#  './dogscats/train/cat.10831.jpg',
#  './dogscats/train/cat.10832.jpg',
#  './dogscats/train/cat.10833.jpg',
#  './dogscats/train/cat.10834.jpg',
#  './dogscats/train/cat.10835.jpg',
#  './dogscats/train/cat.10836.jpg',
#  './dogscats/train/cat.10837.jpg',
#  './dogscats/train/cat.10838.jpg',
#  './dogscats/train/cat.10839.jpg',
#  './dogscats/train/cat.1084.jpg',
#  './dogscats/train/cat.10840.jpg',
#  './dogscats/train/cat.10841.jpg',
#  './dogscats/train/cat.10842.jpg',
#  './dogscats/train/cat.10843.jpg',
#  './dogscats/train/cat.10844.jpg',
#  './dogscats/train/cat.10845.jpg',
#  './dogscats/train/cat.10846.jpg',
#  './dogscats/train/cat.10847.jpg',
#  './dogscats/train/cat.10848.jpg',
#  './dogscats/train/cat.10849.jpg',
#  './dogscats/train/cat.1085.jpg',
#  './dogscats/train/cat.10850.jpg',
#  './dogscats/train/cat.10851.jpg',
#  './dogscats/train/cat.10852.jpg',
#  './dogscats/train/cat.10853.jpg',
#  './dogscats/train/cat.10854.jpg',
#  './dogscats/train/cat.10855.jpg',
#  './dogscats/train/cat.10856.jpg',
#  './dogscats/train/cat.10857.jpg',
#  './dogscats/train/cat.10858.jpg',
#  './dogscats/train/cat.10859.jpg',
#  './dogscats/train/cat.1086.jpg',
#  './dogscats/train/cat.10860.jpg',
#  './dogscats/train/cat.10861.jpg',
#  './dogscats/train/cat.10862.jpg',
#  './dogscats/train/cat.10863.jpg',
#  './dogscats/train/cat.10864.jpg',
#  './dogscats/train/cat.10865.jpg',
#  './dogscats/train/cat.10866.jpg',
#  './dogscats/train/cat.10867.jpg',
#  './dogscats/train/cat.10868.jpg',
#  './dogscats/train/cat.10869.jpg',
#  './dogscats/train/cat.1087.jpg',
#  './dogscats/train/cat.10870.jpg',
#  './dogscats/train/cat.10871.jpg',
#  './dogscats/train/cat.10872.jpg',
#  './dogscats/train/cat.10873.jpg',
#  './dogscats/train/cat.10874.jpg',
#  './dogscats/train/cat.10875.jpg',
#  './dogscats/train/cat.10876.jpg',
#  './dogscats/train/cat.10877.jpg',
#  './dogscats/train/cat.10878.jpg',
#  './dogscats/train/cat.10879.jpg',
#  './dogscats/train/cat.1088.jpg',
#  './dogscats/train/cat.10880.jpg',
#  './dogscats/train/cat.10881.jpg',
#  './dogscats/train/cat.10882.jpg',
#  './dogscats/train/cat.10883.jpg',
#  './dogscats/train/cat.10884.jpg',
#  './dogscats/train/cat.10885.jpg',
#  './dogscats/train/cat.10886.jpg',
#  './dogscats/train/cat.10887.jpg',
#  './dogscats/train/cat.10888.jpg',
#  './dogscats/train/cat.10889.jpg',
#  './dogscats/train/cat.1089.jpg',
#  './dogscats/train/cat.10890.jpg',
#  './dogscats/train/cat.10891.jpg',
#  './dogscats/train/cat.10892.jpg',
#  './dogscats/train/cat.10893.jpg',
#  './dogscats/train/cat.10894.jpg',
#  './dogscats/train/cat.10895.jpg',
#  './dogscats/train/cat.10896.jpg',
#  './dogscats/train/cat.10897.jpg',
#  ...]

# %%
len(train_images)
# Out:
# 25000

# %%
train_images[1000]
# Out:
# './dogscats/train/cat.10898.jpg'

# %% [markdown]
# ### リストの内包表記

# %%
train_dogs =   [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR) if 'dog' in i]

# %%
train_cats =   [TRAIN_DIR+i for i in os.listdir(TRAIN_DIR) if 'cat' in i]

# %%
len(train_dogs)
# Out:
# 12500

# %%
len(train_cats)
# Out:
# 12500

# %%
test_images =  [TEST_DIR+i for i in os.listdir(TEST_DIR)]

# %%
len(test_images)
# Out:
# 12500

# %% [markdown]
# ### リストのスライス処理

# %%
train_images = train_dogs[:1000] + train_cats[:1000]

# %%
len(train_images)
# Out:
# 2000

# %%
random.shuffle(train_images)

# %%
test_images =  test_images[:25]

# %%
len(test_images)
# Out:
# 25

# %% [markdown]
# ### 画像ファイルを多次元配列に変換する

# %%
def read_image(file_path):
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    return cv2.resize(img, (ROWS, COLS), interpolation=cv2.INTER_CUBIC)

# %%
def prep_data(images):
    count = len(images)
    data = np.ndarray((count, CHANNELS, ROWS, COLS), dtype=np.uint8)
    
    for i, image_file in enumerate(images):
        image = read_image(image_file)
        data[i] = image.T #transpose mxn > nxm
        if i%250 == 0: print('Processed {} of {}'.format(i, count))
            
    return data

# %%
train = prep_data(train_images)
test = prep_data(test_images)
# Out:
# Processed 0 of 2000
# Processed 250 of 2000
# Processed 500 of 2000
# Processed 750 of 2000
# Processed 1000 of 2000
# Processed 1250 of 2000
# Processed 1500 of 2000
# Processed 1750 of 2000
# Processed 0 of 25

# %%
train.shape
# Out:
# (2000, 3, 64, 64)

# %%
test.shape
# Out:
# (25, 3, 64, 64)

# %% [markdown]
# ### ラベル一覧をリスト型変数に格納しよう

# %%
labels = []
for i in train_images:
    if 'dog.' in i:
        labels.append(1)
    else:
        labels.append(0)

# %%
labels[0:10]
# Out:
# [1, 0, 1, 0, 1, 1, 1, 0, 0, 1]

# %%
train_images[0:10]
# Out:
# ['./dogscats/train/dog.10814.jpg',
#  './dogscats/train/cat.10513.jpg',
#  './dogscats/train/dog.10196.jpg',
#  './dogscats/train/cat.10649.jpg',
#  './dogscats/train/dog.10258.jpg',
#  './dogscats/train/dog.10808.jpg',
#  './dogscats/train/dog.10036.jpg',
#  './dogscats/train/cat.10766.jpg',
#  './dogscats/train/cat.10460.jpg',
#  './dogscats/train/dog.10356.jpg']

# %%
sns.countplot(labels)
plt.title('Cats and Dogs')
# Out:
# Text(0.5, 1.0, 'Cats and Dogs')

# %% [markdown]
# ### 画像データの確認

# %%
def show_cats_and_dogs(idx):
    cat = read_image(train_cats[idx])
    dog = read_image(train_dogs[idx])
    pair = np.concatenate((cat, dog), axis=1)
    plt.figure(figsize=(10,5))
    plt.imshow(pair)
    plt.show()

# %%
for idx in range(10,15):
    show_cats_and_dogs(idx)

# %% [markdown]
# ### ピクセル値を平均して画像を生成する

# %%
dog_avg = np.array([dog[0].T for i, dog in enumerate(train) if labels[i]==1]).mean(axis=0)
plt.imshow(dog_avg)
plt.title('Your Average Dog')
# Out:
# Text(0.5, 1.0, 'Your Average Dog')

# %%
cat_avg = np.array([cat[0].T for i, cat in enumerate(train) if labels[i]==0]).mean(axis=0)
plt.imshow(cat_avg)
plt.title('Your Average Cat')
# Out:
# Text(0.5, 1.0, 'Your Average Cat')

# %% [markdown]
# ### CatdogNet-16 を定義しよう

# %%
from keras.models import Sequential
from keras.layers import Input, Dropout, Flatten, Conv2D, MaxPooling2D, Dense, Activation
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
optimizer = RMSprop(lr=1e-4)
objective = 'binary_crossentropy'

def catdog():
    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=(3, ROWS, COLS), activation='relu'))
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_first", pool_size=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_first", pool_size=(2, 2)))
    
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_first", pool_size=(2, 2)))
    
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
#     model.add(Convolution2D(256, 3, 3, border_mode='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_first", pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss=objective, optimizer=optimizer, metrics=['accuracy'])
    return model

model = catdog()

# %% [markdown]
# ### トレーニングを実行しよう

# %%
nb_epoch = 10
batch_size = 16

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))

# monitor: 監視対象
# patience: 訓練が停止し，値が改善しなくなってからのエポック数．
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')

def run_catdog():
    
    history = LossHistory()
    model.fit(train, labels, batch_size=batch_size, epochs=nb_epoch,
              validation_split=0.25, verbose=0, shuffle=True, callbacks=[history, early_stopping])
    

    predictions = model.predict(test, verbose=0)
    return predictions, history

predictions, history = run_catdog()
# タプルで受け取る

# %% [markdown]
# ### ロスをプロットしよう

# %%
loss = history.losses
val_loss = history.val_losses

plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.title('CatdogNet Loss Trend')
plt.plot(loss, 'blue', label='Training Loss')
plt.plot(val_loss, 'green', label='Validation Loss')
plt.xticks(range(0,nb_epoch)[0::2])
plt.legend()
plt.show()

# %% [markdown]
# ### 推定結果を可視化しよう

# %%
for i in range(0,10):
    if predictions[i, 0] >= 0.5:
        print('I am {:.2%} sure this is a Dog'.format(predictions[i][0]))
    else:
        print('I am {:.2%} sure this is a Cat'.format(1-predictions[i][0]))
        
    plt.imshow(test[i].T)
    plt.show()
# Out:
# I am 55.67% sure this is a Cat
# I am 64.66% sure this is a Cat
# I am 68.66% sure this is a Cat
# I am 74.33% sure this is a Dog
# I am 70.39% sure this is a Dog
# I am 68.02% sure this is a Dog
# I am 52.37% sure this is a Dog
# I am 77.71% sure this is a Dog
# I am 61.19% sure this is a Dog
# I am 52.39% sure this is a Cat
